# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Importing the dataset
df = pd.read_csv("jobs_in_data.csv")
df.describe()
df.size
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9355 entries, 0 to 9354
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           9355 non-null   int64
#  1   job_title           9355 non-null   object
#  2   job_category        9355 non-null   object
#  3   salary_currency     9355 non-null   object
#  4   salary              9355 non-null   int64
#  5   salary_in_usd       9355 non-null   int64
#  6   employee_residence  9355 non-null   object
#  7   experience_level    9355 non-null   object
#  8   employment_type     9355 non-null   object
#  9   work_setting        9355 non-null   object
#  10  company_location    9355 non-null   object
#  11  company_size        9355 non-null   object
# dtypes: int64(3), object(9)
# memory usage: 877.2+ KB
#    work_year             job_title                    job_category  \
# ...

# %%
print(df['job_title'].nunique())
df['job_title'].value_counts()
df['job_title'].value_counts().head(10).plot(kind='bar')
plt.show()

print(df['experience_level'].unique())
# Out:
# 125
# ['Mid-level' 'Senior' 'Executive' 'Entry-level']

# %%
# df['employee_residence'].value_counts().head(10).plot(kind='bar')

spain = df.loc[(df['company_location'] == "Spain") & (df['experience_level'] == 'Entry-level' )]
#plot spain jobtitle and salary
spain['job_title'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='job_title'>
